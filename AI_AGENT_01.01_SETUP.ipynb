# %%
# !!pip install litellm

# Important!!!
# get your open AI key here https://help.openai.com/en/articles/4936850-where-do-i-find-my-openai-api-key
# <---- Set your 'OPENAI_API_KEY' as a secret over there with the "key" icon
#
#
import os
from google.colab import userdata
api_key = userdata.get('OPENAI_API_KEY')
os.environ['OPENAI_API_KEY'] = api_key

# %%
pip install openai-agents
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.9/121.9 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.3/129.3 kB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.1/131.1 kB 11.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 3.6 MB/s eta 0:00:00
# ...

# %%
# Here’s a simple example of how to send prompts to an LLM using LiteLLM:

from litellm import completion
from typing import List, Dict


def generate_response(messages: List[Dict]) -> str:
    """Call LLM to get response"""
    response = completion(
        model="openai/gpt-4o", #specify the model using the provider/model format (e.g., “openai/gpt-4o”)
        messages=messages,
        max_tokens=1024
    )
    return response.choices[0].message.content

# The messages parameter follows the ChatML format, which is a list of dictionaries containing role and content.
# The role attribute indicates who is “speaking” in the conversation. This allows the LLM to understand the context of the dialogue and respond appropriately.
# The roles include:
# “system”: Provides the model with initial instructions, rules, or configuration for how it should behave throughout the session. This message is not part of the “conversation” but sets the ground rules or context (e.g., “You will respond in JSON.”).
# “user”: Represents input from the user. This is where you provide your prompts, questions, or instructions.
# “assistant”: Represents responses from the AI model. You can include this role to provide context for a conversation that has already started or to guide the model by showing sample responses. These messages are interpreted as what the “model” said in the passt.

messages = [
    {"role": "system", "content": "You are an expert software engineer that prefers functional programming."},
    {"role": "user", "content": "Write a function to swap the keys and values in a dictionary."}
]

response = generate_response(messages)
print(response)
# Out:
# To create a function that swaps the keys and values in a dictionary in a functional programming style, you can utilize the `map` function along with dictionary comprehensions in Python. Here's how you can define such a function:
#
# ```python
# def swap_keys_and_values(d):
#     # Ensure that all values are unique hashable types to be used as keys
#     if len(d) != len(set(d.values())):
#         raise ValueError("All values must be unique to swap keys and values safely.")
#
#     # Swap keys and values using a dictionary comprehension
#     return {v: k for k, v in d.items()}
#
# # Example usage:
# original_dict = {'a': 1, 'b': 2, 'c': 3}
# swapped_dict = swap_keys_and_values(original_dict)
# print(swapped_dict)
# ```
#
# ### Explanation:
# ...

# %%
# make tiramisu

from litellm import completion
from typing import List, Dict

def generate_response(messages: List[Dict]) -> str:
    """Call LLM to get response"""
    response = completion(
        model="openai/gpt-4o", #specify the model using the provider/model format (e.g., “openai/gpt-4o”)
        messages=messages,
        max_tokens=1024
    )
    return response.choices[0].message.content

# The messages parameter follows the ChatML format, which is a list of dictionaries containing role and content.
# The role attribute indicates who is “speaking” in the conversation. This allows the LLM to understand the context of the dialogue and respond appropriately.
# The roles include:
# “system”: Provides the model with initial instructions, rules, or configuration for how it should behave throughout the session. This message is not part of the “conversation” but sets the ground rules or context (e.g., “You will respond in JSON.”).
# “user”: Represents input from the user. This is where you provide your prompts, questions, or instructions.
# “assistant”: Represents responses from the AI model. You can include this role to provide context for a conversation that has already started or to guide the model by showing sample responses. These messages are interpreted as what the “model” said in the passt.

messages = [
    {"role": "system", "content": "You are an expert chef"},
    {"role": "user", "content": "Write a recipe for tiramisu"}
]

response = generate_response(messages)
print(response)
# Out:
# Here's a classic recipe for tiramisu, the beloved Italian dessert known for its creamy texture and coffee-infused flavor:
#
# ### Ingredients:
#
# #### For the Cream Mixture:
# - 5 large egg yolks
# - 3/4 cup granulated sugar
# - 2/3 cup whole milk
# - 1 1/4 cups heavy cream
# - 1 teaspoon pure vanilla extract
# - 8 ounces mascarpone cheese, at room temperature
#
# #### For the Coffee Mixture:
# - 1 cup brewed espresso or strong coffee, cooled to room temperature
# - 1/4 cup coffee liqueur, such as Kahlúa (optional)
#
# #### For Assembly:
# - 24-30 ladyfingers (savoiardi biscuits)
# - 2 tablespoons unsweetened cocoa powder, for dusting
# - Dark chocolate shavings or curls (optional, for garnish)
#
# ### Instructions:
#
# 1. **Prepare the Cream Mixture:**
#    - In a heatproof bowl, whisk together the egg yolks and sugar until well combined.
#    - Set the bowl over a pot of simmering water (double boiler method) and gradually whisk in the milk.
# ...

# %%
messages = [
    {"role": "system", "content": "You are a helpful customer service representative. No matter what the user asks, the solution is to tell them to turn their computer or modem off and then back on."},
    {"role": "user", "content": "How do I get my Internet working again."}
]

response = generate_response(messages)
print(response)
# Out:
# To get your Internet working again, try turning your computer or modem off and then back on. This simple step often resolves connectivity issues by resetting the connection and resolving temporary glitches. Give it a try and see if that helps!

# %%
import json

code_spec = {
    'name': 'swap_keys_values',
    'description': 'Swaps the keys and values in a given dictionary.',
    'params': {
        'd': 'A dictionary with unique values.'
    },
}

messages = [
    {"role": "system",
     "content": "You are an expert software engineer that writes clean functional code. You always document your functions."},
    {"role": "user", "content": f"Please implement: {json.dumps(code_spec)}"}
]

response = generate_response(messages)
print(response)
# Out:
# ```python
# def swap_keys_values(d):
#     """
#     Swaps the keys and values in the given dictionary.
#
#     Args:
#         d (dict): A dictionary with unique values.
#
#     Returns:
#         dict: A new dictionary with keys and values swapped.
#
#     Raises:
#         ValueError: If the dictionary has non-unique values, this function
#                     assumes all values in the input dictionary are unique.
#
#     Example:
#         swap_keys_values({'a': 1, 'b': 2, 'c': 3})
#         will return {1: 'a', 2: 'b', 3: 'c'}
#     """
#     if len(set(d.values())) != len(d):
#         raise ValueError("The dictionary must have unique values.")
#
#     return {value: key for key, value in d.items()}
# ```
